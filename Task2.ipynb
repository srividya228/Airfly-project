# %%
# Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Load dataset
df = pd.read_csv("/content/flights_sample_3m.csv")

print("\n--- Shape of dataset ---")
print(df.shape)

print("\n--- Data Types & Nulls ---")
print(df.info())
# Out:
# --- Shape of dataset ---
# (245877, 32)
#
# --- Data Types & Nulls ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245877 entries, 0 to 245876
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FL_DATE                  245877 non-null  object
#  1   AIRLINE                  245877 non-null  object
#  2   AIRLINE_DOT              245877 non-null  object
#  3   AIRLINE_CODE             245877 non-null  object
#  4   DOT_CODE                 245877 non-null  int64
#  5   FL_NUMBER                245877 non-null  int64
#  6   ORIGIN                   245877 non-null  object
#  7   ORIGIN_CITY              245877 non-null  object
#  8   DEST                     245877 non-null  object
#  9   DEST_CITY                245877 non-null  object
#  10  CRS_DEP_TIME             245877 non-null  int64
#  11  DEP_TIME                 239439 non-null  float64
#  12  DEP_DELAY                239436 non-null  float64
#  13  TAXI_OUT                 239358 non-null  float64
#  14  WHEELS_OFF               239358 non-null  float64
#  15  WHEELS_ON                239265 non-null  float64
#  16  TAXI_IN                  239264 non-null  float64
#  17  CRS_ARR_TIME             245876 non-null  float64
#  18  ARR_TIME                 239264 non-null  float64
#  19  ARR_DELAY                238790 non-null  float64
#  20  CANCELLED                245876 non-null  float64
#  21  CANCELLATION_CODE        6548 non-null    object
#  22  DIVERTED                 245876 non-null  float64
#  23  CRS_ELAPSED_TIME         245874 non-null  float64
#  24  ELAPSED_TIME             238790 non-null  float64
#  25  AIR_TIME                 238790 non-null  float64
#  26  DISTANCE                 245876 non-null  float64
#  27  DELAY_DUE_CARRIER        43814 non-null   float64
#  28  DELAY_DUE_WEATHER        43814 non-null   float64
#  29  DELAY_DUE_NAS            43814 non-null   float64
#  30  DELAY_DUE_SECURITY       43814 non-null   float64
#  31  DELAY_DUE_LATE_AIRCRAFT  43814 non-null   float64
# dtypes: float64(20), int64(3), object(9)
# memory usage: 60.0+ MB
# None

# %%
# Basic Info

print("\n--- Descriptive Stats ---")
print(df.describe(include='all'))
display(df.describe(include="all"))
# Out:
# --- Descriptive Stats ---
#            FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# count        15361                   15361                       15361
# unique        1699                      18                          18
# top     2019-09-27  Southwest Airlines Co.  Southwest Airlines Co.: WN
# freq            22                    2972                        2972
# mean           NaN                     NaN                         NaN
# std            NaN                     NaN                         NaN
# min            NaN                     NaN                         NaN
# 25%            NaN                     NaN                         NaN
# 50%            NaN                     NaN                         NaN
# 75%            NaN                     NaN                         NaN
# max            NaN                     NaN                         NaN
#
#        AIRLINE_CODE      DOT_CODE     FL_NUMBER ORIGIN  ORIGIN_CITY   DEST  \
# count         15361  15360.000000  15360.000000  15360        15360  15360
# unique           19           NaN           NaN    336          330    325
# top              WN           NaN           NaN    ATL  Atlanta, GA    ATL
# freq           2972           NaN           NaN    810          810    820
# mean            NaN  19973.896484   2517.907357    NaN          NaN    NaN
# std             NaN    378.268293   1745.077372    NaN          NaN    NaN
# min             NaN  19393.000000      1.000000    NaN          NaN    NaN
# 25%             NaN  19790.000000   1064.000000    NaN          NaN    NaN
# 50%             NaN  19930.000000   2161.000000    NaN          NaN    NaN
# 75%             NaN  20368.000000   3793.000000    NaN          NaN    NaN
# max             NaN  20452.000000   8799.000000    NaN          NaN    NaN
#
#           DEST_CITY  ...      DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# count         15360  ...  15360.000000      15360.000000  14956.000000
# unique          320  ...           NaN               NaN           NaN
# top     Atlanta, GA  ...           NaN               NaN           NaN
# freq            820  ...           NaN               NaN           NaN
# mean            NaN  ...      0.001888        142.241146    136.481680
# std             NaN  ...      0.043412         71.123494     71.067448
# min             NaN  ...      0.000000         21.000000     18.000000
# 25%             NaN  ...      0.000000         90.000000     84.000000
# 50%             NaN  ...      0.000000        125.000000    119.000000
# 75%             NaN  ...      0.000000        174.000000    168.000000
# max             NaN  ...      1.000000        665.000000    722.000000
#
#            AIR_TIME      DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  \
# count   14956.00000  15360.000000        2727.000000        2727.000000
# unique          NaN           NaN                NaN                NaN
# top             NaN           NaN                NaN                NaN
# freq            NaN           NaN                NaN                NaN
# mean      112.20226    807.938281          24.357902           4.145948
# std        69.12528    583.439640          63.831281          37.902460
# min         9.00000     30.000000           0.000000           0.000000
# 25%        62.00000    382.750000           0.000000           0.000000
# 50%        95.00000    651.000000           5.000000           0.000000
# 75%       142.00000   1046.000000          24.000000           0.000000
# max       661.00000   5095.000000        1022.000000        1180.000000
#
#         DELAY_DUE_NAS  DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# count     2727.000000         2727.000000              2727.000000
# unique            NaN                 NaN                      NaN
# top               NaN                 NaN                      NaN
# freq              NaN                 NaN                      NaN
# mean        12.526219            0.172351                23.914558
# std         32.341231            4.029650                53.915048
# min          0.000000            0.000000                 0.000000
# 25%          0.000000            0.000000                 0.000000
# 50%          0.000000            0.000000                 0.000000
# 75%         17.000000            0.000000                27.000000
# max       1124.000000          154.000000              1049.000000
#
# [11 rows x 32 columns]
#            FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# count        15361                   15361                       15361
# unique        1699                      18                          18
# top     2019-09-27  Southwest Airlines Co.  Southwest Airlines Co.: WN
# freq            22                    2972                        2972
# mean           NaN                     NaN                         NaN
# std            NaN                     NaN                         NaN
# min            NaN                     NaN                         NaN
# 25%            NaN                     NaN                         NaN
# 50%            NaN                     NaN                         NaN
# 75%            NaN                     NaN                         NaN
# max            NaN                     NaN                         NaN
#
#        AIRLINE_CODE      DOT_CODE     FL_NUMBER ORIGIN  ORIGIN_CITY   DEST  \
# count         15361  15360.000000  15360.000000  15360        15360  15360
# unique           19           NaN           NaN    336          330    325
# top              WN           NaN           NaN    ATL  Atlanta, GA    ATL
# freq           2972           NaN           NaN    810          810    820
# mean            NaN  19973.896484   2517.907357    NaN          NaN    NaN
# std             NaN    378.268293   1745.077372    NaN          NaN    NaN
# min             NaN  19393.000000      1.000000    NaN          NaN    NaN
# 25%             NaN  19790.000000   1064.000000    NaN          NaN    NaN
# 50%             NaN  19930.000000   2161.000000    NaN          NaN    NaN
# 75%             NaN  20368.000000   3793.000000    NaN          NaN    NaN
# max             NaN  20452.000000   8799.000000    NaN          NaN    NaN
#
#           DEST_CITY  ...      DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# count         15360  ...  15360.000000      15360.000000  14956.000000
# unique          320  ...           NaN               NaN           NaN
# top     Atlanta, GA  ...           NaN               NaN           NaN
# freq            820  ...           NaN               NaN           NaN
# mean            NaN  ...      0.001888        142.241146    136.481680
# std             NaN  ...      0.043412         71.123494     71.067448
# min             NaN  ...      0.000000         21.000000     18.000000
# 25%             NaN  ...      0.000000         90.000000     84.000000
# 50%             NaN  ...      0.000000        125.000000    119.000000
# 75%             NaN  ...      0.000000        174.000000    168.000000
# max             NaN  ...      1.000000        665.000000    722.000000
#
#            AIR_TIME      DISTANCE  DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  \
# count   14956.00000  15360.000000        2727.000000        2727.000000
# unique          NaN           NaN                NaN                NaN
# top             NaN           NaN                NaN                NaN
# freq            NaN           NaN                NaN                NaN
# mean      112.20226    807.938281          24.357902           4.145948
# std        69.12528    583.439640          63.831281          37.902460
# min         9.00000     30.000000           0.000000           0.000000
# 25%        62.00000    382.750000           0.000000           0.000000
# 50%        95.00000    651.000000           5.000000           0.000000
# 75%       142.00000   1046.000000          24.000000           0.000000
# max       661.00000   5095.000000        1022.000000        1180.000000
#
#         DELAY_DUE_NAS  DELAY_DUE_SECURITY  DELAY_DUE_LATE_AIRCRAFT
# count     2727.000000         2727.000000              2727.000000
# unique            NaN                 NaN                      NaN
# top               NaN                 NaN                      NaN
# freq              NaN                 NaN                      NaN
# mean        12.526219            0.172351                23.914558
# std         32.341231            4.029650                53.915048
# min          0.000000            0.000000                 0.000000
# 25%          0.000000            0.000000                 0.000000
# 50%          0.000000            0.000000                 0.000000
# 75%         17.000000            0.000000                27.000000
# max       1124.000000          154.000000              1049.000000
#
# [11 rows x 32 columns]

# %%
# Handle Missing Values

print("\n--- Missing Values ---")
print(df.isnull().sum())

# Fill categorical NaNs with "Unknown"
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].fillna("Unknown")
# Out:
# --- Missing Values ---
# FL_DATE                         0
# AIRLINE                         0
# AIRLINE_DOT                     0
# AIRLINE_CODE                    0
# DOT_CODE                        0
# FL_NUMBER                       0
# ORIGIN                          0
# ORIGIN_CITY                     0
# DEST                            0
# DEST_CITY                       0
# CRS_DEP_TIME                    0
# DEP_TIME                     6438
# DEP_DELAY                    6441
# TAXI_OUT                     6519
# WHEELS_OFF                   6519
# WHEELS_ON                    6612
# TAXI_IN                      6613
# CRS_ARR_TIME                    1
# ARR_TIME                     6613
# ARR_DELAY                    7087
# CANCELLED                       1
# CANCELLATION_CODE          239329
# DIVERTED                        1
# CRS_ELAPSED_TIME                3
# ELAPSED_TIME                 7087
# AIR_TIME                     7087
# DISTANCE                        1
# DELAY_DUE_CARRIER          202063
# DELAY_DUE_WEATHER          202063
# DELAY_DUE_NAS              202063
# DELAY_DUE_SECURITY         202063
# DELAY_DUE_LATE_AIRCRAFT    202063
# dtype: int64

# %%
# --- Derived Features ---

# Ensure FL_DATE is datetime
if 'FL_DATE' in df.columns:
    df['FL_DATE'] = pd.to_datetime(df['FL_DATE'], errors='coerce')

    # Month, Day of Week
    df['MONTH'] = df['FL_DATE'].dt.month
    df['DAY_OF_WEEK'] = df['FL_DATE'].dt.day_name()

# Extract Hour from DEP_TIME if present
if 'DEP_TIME' in df.columns:
    # Convert hhmm to hour safely
    df['DEP_HOUR'] = (df['DEP_TIME'] // 100).astype('Int64')
else:
    df['DEP_HOUR'] = None

# Create Route if ORIGIN and DEST are available
if 'ORIGIN' in df.columns and 'DEST' in df.columns:
    df['ROUTE'] = df['ORIGIN'].astype(str) + " → " + df['DEST'].astype(str)
else:
    df['ROUTE'] = None

# Only print columns that exist
cols_to_show = [col for col in ['FL_DATE','MONTH','DAY_OF_WEEK','DEP_HOUR','ROUTE'] if col in df.columns]
print(df[cols_to_show].head())
# Out:
#      FL_DATE  MONTH DAY_OF_WEEK  DEP_HOUR      ROUTE
# 0 2019-01-09      1   Wednesday        11  FLL → EWR
# 1 2022-11-19     11    Saturday        21  MSP → SEA
# 2 2022-07-22      7      Friday        10  DEN → MSP
# 3 2023-03-06      3      Monday        16  MSP → SFO
# 4 2020-02-23      2      Sunday        18  MCO → DFW

# %%
# --- Save Preprocessed Data ---
df.to_csv("flights_preprocessed.csv", index=False)
print("Preprocessed dataset saved as flights_preprocessed.csv")
# Out:
# Preprocessed dataset saved as flights_preprocessed.csv

# %%
# --- Feature Dictionary ---
feature_dict = {
    "FL_DATE": "Flight date (datetime)",
    "MONTH": "Month of flight (1–12)",
    "DAY_OF_WEEK": "Day of week (Monday–Sunday)",
    "DEP_HOUR": "Scheduled departure hour (0–23)",
    "ROUTE": "Origin → Destination route",
    # Add more key variables here
}
for k,v in feature_dict.items():
    print(f"{k}: {v}")
# Out:
# FL_DATE: Flight date (datetime)
# MONTH: Month of flight (1–12)
# DAY_OF_WEEK: Day of week (Monday–Sunday)
# DEP_HOUR: Scheduled departure hour (0–23)
# ROUTE: Origin → Destination route

# %%
# Time-based Analysis (if date columns exist)
if 'FL_DATE' in df.columns:
    df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
    flights_per_month = df.groupby(df['FL_DATE'].dt.to_period('M')).size()
    flights_per_month.plot(kind='bar', figsize=(10,4))

# %%
# Pairplot (using sample to avoid memory issues)

sample_df = df.sample(5000, random_state=42)
sns.pairplot(sample_df[['ARR_DELAY','DEP_DELAY','AIR_TIME','DISTANCE']])
plt.show()

# %% [markdown]
# Milestone2

# %%
# Load dataset
df = pd.read_csv("/content/flights_preprocessed.csv")

# --- Top Airlines ---
if 'OP_CARRIER' in df.columns:
    df['OP_CARRIER'].value_counts().head(10).plot(kind='bar', figsize=(8,4))
    plt.title("Top 10 Airlines by Flight Count")
    plt.show()

# --- Top Routes ---
if 'ROUTE' in df.columns:
    df['ROUTE'].value_counts().head(10).plot(kind='bar', figsize=(10,4))
    plt.title("Top 10 Routes")
    plt.show()

# --- Busiest Months ---
if 'MONTH' in df.columns:
    df['MONTH'].value_counts().sort_index().plot(kind='bar', figsize=(8,4))
    plt.title("Flights by Month")
    plt.show()

# %%
#  Flight Distribution by Day of Week & Hour
# --- Flights by Day of Week ---
if 'DAY_OF_WEEK' in df.columns:
    df['DAY_OF_WEEK'].value_counts().reindex([
        'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'
    ]).plot(kind='bar', figsize=(8,4))
    plt.title("Flights by Day of Week")
    plt.show()

# --- Flights by Departure Hour ---
if 'DEP_HOUR' in df.columns and df['DEP_HOUR'].notna().any():
    df['DEP_HOUR'].value_counts().sort_index().plot(kind='bar', figsize=(10,4))
    plt.title("Flights by Departure Hour")
    plt.show()

# %%
# --- Delay Cause Analysis (Safe) ---
delay_cols = ['CARRIER_DELAY','WEATHER_DELAY','NAS_DELAY','SECURITY_DELAY','LATE_AIRCRAFT_DELAY']

for col in delay_cols:
    if col in df.columns:
        if df[col].notna().sum() > 0 and df[col].sum() > 0:
            plt.figure(figsize=(8,4))
            df[col].dropna().plot(kind='hist', bins=30, alpha=0.6)
            plt.title(f"Distribution of {col}")
            plt.xlabel("Minutes Delay")
            plt.ylabel("Count")
            plt.show()
        else:
            print(f"Column {col} has no meaningful values (all NaN or zero).")
    else:
        print(f" Column {col} not found in dataset.")
# Out:
#  Column CARRIER_DELAY not found in dataset.
#  Column WEATHER_DELAY not found in dataset.
#  Column NAS_DELAY not found in dataset.
#  Column SECURITY_DELAY not found in dataset.
#  Column LATE_AIRCRAFT_DELAY not found in dataset.

# %%
# --- Average Delay by Airline (Safe) ---

# Try multiple possible column names for carrier and arrival delay
carrier_col = None
for c in ['OP_CARRIER','AIRLINE','CARRIER','UniqueCarrier']:
    if c in df.columns:
        carrier_col = c
        break

arr_delay_col = None
for c in ['ARR_DELAY','ARRIVAL_DELAY','ArrDelay']:
    if c in df.columns:
        arr_delay_col = c
        break

if carrier_col and arr_delay_col:
    avg_delay = df.groupby(carrier_col)[arr_delay_col].mean().dropna().sort_values(ascending=False).head(10)
    if not avg_delay.empty:
        avg_delay.plot(kind='bar', figsize=(8,4))
        plt.title("Top 10 Airlines by Average Arrival Delay")
        plt.ylabel("Average Delay (minutes)")
        plt.xlabel("Airline")
        plt.show()
    else:
        print(f" Column {arr_delay_col} has no valid values to plot.")
else:
    print(" Could not find suitable columns for airline or arrival delay in dataset.")

# %%
# --- Average Delay by Origin Airport ---
if 'ORIGIN' in df.columns and 'ARR_DELAY' in df.columns:
    avg_delay_airport = df.groupby('ORIGIN')['ARR_DELAY'].mean().sort_values(ascending=False).head(10)
    avg_delay_airport.plot(kind='bar', figsize=(10,4))
    plt.title("Top 10 Airports by Average Arrival Delay")
    plt.ylabel("Average Delay (minutes)")
    plt.show()

# %%
#  Distance vs Arrival Delay
if 'DISTANCE' in df.columns and 'ARR_DELAY' in df.columns:
    # Create bins of distance (e.g., every 500 miles)
    df['DISTANCE_BIN'] = pd.cut(df['DISTANCE'], bins=range(0, int(df['DISTANCE'].max())+500, 500))
    avg_delay = df.groupby('DISTANCE_BIN')['ARR_DELAY'].mean().reset_index()

    plt.figure(figsize=(10,5))
    sns.lineplot(x=avg_delay['DISTANCE_BIN'].astype(str), y=avg_delay['ARR_DELAY'], marker="o")
    plt.title("Average Arrival Delay by Distance Group")
    plt.xlabel("Flight Distance (binned, miles)")
    plt.ylabel("Average Delay (minutes)")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipython-input-810850537.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_delay = df.groupby('DISTANCE_BIN')['ARR_DELAY'].mean().reset_index()

# %%
#  Boxplot of Delays by Airline

if 'ARR_DELAY' in df.columns and 'OP_UNIQUE_CARRIER' in df.columns:
    plt.figure(figsize=(12,6))
    sns.boxplot(x='OP_UNIQUE_CARRIER', y='ARR_DELAY', data=df)
    plt.title("Distribution of Arrival Delays by Airline")
    plt.xlabel("Airline")
    plt.ylabel("Arrival Delay (minutes)")
    plt.xticks(rotation=45)
    plt.show()

# %%
# --- Flights per Year ---
if 'FL_DATE' in df.columns:
    df['FL_DATE'] = pd.to_datetime(df['FL_DATE'], errors='coerce')
    flights_per_year = df.groupby(df['FL_DATE'].dt.year).size()

    flights_per_year.plot(kind='bar', figsize=(8,4))
    plt.title("Flights per Year")
    plt.xlabel("Year")
    plt.ylabel("Number of Flights")
    plt.show()

# %%
# --- Flights per Month (Across Years) ---
if 'FL_DATE' in df.columns:
    flights_per_month = df.groupby(df['FL_DATE'].dt.month).size()

    flights_per_month.plot(kind='bar', figsize=(8,4))
    plt.title("Flights per Month (Aggregated)")
    plt.xlabel("Month (1 = Jan ... 12 = Dec)")
    plt.ylabel("Number of Flights")
    plt.show()

# %%
# --- Average Arrival Delay per Month ---
if 'FL_DATE' in df.columns and 'ARR_DELAY' in df.columns:
    avg_delay_month = df.groupby(df['FL_DATE'].dt.month)['ARR_DELAY'].mean()

    avg_delay_month.plot(kind='line', marker='o', figsize=(8,4))
    plt.title("Average Arrival Delay per Month")
    plt.xlabel("Month")
    plt.ylabel("Avg Delay (minutes)")
    plt.show()

# %%
# --- Average Arrival Delay per Year ---
if 'FL_DATE' in df.columns and 'ARR_DELAY' in df.columns:
    avg_delay_year = df.groupby(df['FL_DATE'].dt.year)['ARR_DELAY'].mean()

    avg_delay_year.plot(kind='line', marker='o', figsize=(8,4))
    plt.title("Average Arrival Delay per Year")
    plt.xlabel("Year")
    plt.ylabel("Avg Delay (minutes)")
    plt.show()
